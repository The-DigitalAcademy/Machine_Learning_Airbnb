# %%
# !!pip install mlxtend
# Out:
# ['Requirement already satisfied: mlxtend in /Users/da_m1_52/anaconda3/lib/python3.10/site-packages (0.22.0)',
#  'Requirement already satisfied: joblib>=0.13.2 in /Users/da_m1_52/anaconda3/lib/python3.10/site-packages (from mlxtend) (1.1.1)',
#  'Requirement already satisfied: scikit-learn>=1.0.2 in /Users/da_m1_52/anaconda3/lib/python3.10/site-packages (from mlxtend) (1.2.2)',
#  'Requirement already satisfied: setuptools in /Users/da_m1_52/anaconda3/lib/python3.10/site-packages (from mlxtend) (65.6.3)',
#  'Requirement already satisfied: matplotlib>=3.0.0 in /Users/da_m1_52/anaconda3/lib/python3.10/site-packages (from mlxtend) (3.7.0)',
#  'Requirement already satisfied: numpy>=1.16.2 in /Users/da_m1_52/anaconda3/lib/python3.10/site-packages (from mlxtend) (1.23.5)',
#  'Requirement already satisfied: pandas>=0.24.2 in /Users/da_m1_52/anaconda3/lib/python3.10/site-packages (from mlxtend) (1.5.3)',
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.ensemble import StackingRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import Ridge
from sklearn import linear_model
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import VarianceThreshold
from sklearn import preprocessing
from sklearn.linear_model import Lasso
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %matplotlib inline

# %%
df= pd.read_csv('/Users/da_m1_52/Downloads/AirBNB_modified.csv', sep = ';')

# %%
df.head()
# Out:
#    Unnamed: 0    id   name  host_id    host_name  neighbourhood_group  \
# 0           0  2539  12321     2787         John                    1
# 1           1  2595  37440     2845     Jennifer                    2
# 2           2  3647  43522     4632    Elisabeth                    2
# 3           3  3831  14776     4869  LisaRoxanne                    1
# 4           4  5022  18684     7192        Laura                    2
#
#    neighbourhood  latitude  longitude  room_type  ...  minimum_nights  \
# 0            108  40.64749  -73.97237          1  ...               1
# 1            127  40.75362  -73.98377          0  ...               1
# 2             94  40.80902  -73.94190          1  ...               3
# 3             41  40.68514  -73.95976          0  ...               1
# 4             61  40.79851  -73.94399          0  ...              10
#
#    number_of_reviews  last_review reviews_per_month  \
# 0                  9   2018-10-19              0.21
# ...

# %%
month_mapping = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12
}

df['Month'] = df['Month'].map(month_mapping)
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48853  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48854  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48855  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48856  36485609               43rd St. Time Square-cozy single bed  30985759
# 48857  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

season_mapping = {
    'Spring': 1,
    'Summer': 2,
    'Autumn': 3,
    'Winter': 4
}

df['Seasons'] = df['Seasons'].map(season_mapping)

le = LabelEncoder()
df['Seasons'] = le.fit_transform(df['Seasons'])
df
# Out:
#              id   name   host_id      host_name  neighbourhood_group  \
# 0          2539  12321      2787           John                    1
# 1          2595  37440      2845       Jennifer                    2
# 2          3647  43522      4632      Elisabeth                    2
# 3          3831  14776      4869    LisaRoxanne                    1
# 4          5022  18684      7192          Laura                    2
# ...         ...    ...       ...            ...                  ...
# 48853  36484665  11640   8232441        Sabrina                    1
# 48854  36485057   3518   6570630        Marisol                    1
# 48855  36485431  42446  23492952  Ilgar & Aysel                    2
# 48856  36485609   2570  30985759            Taz                    2
# 48857  36487245  44517  68119814     Christophe                    2
#
#        neighbourhood  latitude  longitude  room_type  price  minimum_nights  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['room_type'] = le.fit_transform(df['room_type'])
df
# Out:
#              id   name   host_id      host_name  neighbourhood_group  \
# 0          2539  12321      2787           John                    1
# 1          2595  37440      2845       Jennifer                    2
# 2          3647  43522      4632      Elisabeth                    2
# 3          3831  14776      4869    LisaRoxanne                    1
# 4          5022  18684      7192          Laura                    2
# ...         ...    ...       ...            ...                  ...
# 48853  36484665  11640   8232441        Sabrina                    1
# 48854  36485057   3518   6570630        Marisol                    1
# 48855  36485431  42446  23492952  Ilgar & Aysel                    2
# 48856  36485609   2570  30985759            Taz                    2
# 48857  36487245  44517  68119814     Christophe                    2
#
#        neighbourhood  latitude  longitude  room_type  price  minimum_nights  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['neighbourhood_group'] = le.fit_transform(df['neighbourhood_group'])
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48853  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48854  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48855  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48856  36485609               43rd St. Time Square-cozy single bed  30985759
# 48857  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['neighbourhood'] = le.fit_transform(df['neighbourhood'])
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48853  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48854  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48855  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48856  36485609               43rd St. Time Square-cozy single bed  30985759
# 48857  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['name'] = le.fit_transform(df['name'])
df
# Out:
#              id   name   host_id      host_name  neighbourhood_group  \
# 0          2539  12321      2787           John                    1
# 1          2595  37440      2845       Jennifer                    2
# 2          3647  43522      4632      Elisabeth                    2
# 3          3831  14776      4869    LisaRoxanne                    1
# 4          5022  18684      7192          Laura                    2
# ...         ...    ...       ...            ...                  ...
# 48853  36484665  11640   8232441        Sabrina                    1
# 48854  36485057   3518   6570630        Marisol                    1
# 48855  36485431  42446  23492952  Ilgar & Aysel                    2
# 48856  36485609   2570  30985759            Taz                    2
# 48857  36487245  44517  68119814     Christophe                    2
#
#        neighbourhood  latitude  longitude  room_type  price  minimum_nights  \
# ...

# %%
missing_values = df.isnull().sum()
missing_values_per_column = df.isnull().sum(axis=0)
print(missing_values)
print(missing_values_per_column)
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# Day_Of_Week                       0
# Month                             0
# Year                              0
# Seasons                           0
# dtype: int64
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# ...

# %%
# #Save the modified DataFrame back to the CSV file
df.to_csv('/Users/da_m1_52/Downloads/AirBNB_modified.csv', sep=';')

# %%
columns_of_interest = ['name', 'neighbourhood_group', 'neighbourhood', 'room_type', 'price', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365', 'minimum_nights']
summary_stats = df[columns_of_interest].describe()
summary_stats
# Out:
#                name  neighbourhood_group  neighbourhood     room_type  \
# count  48858.000000         48858.000000   48858.000000  48858.000000
# mean   23950.059704             1.675447     107.130910      0.503991
# std    13805.061232             0.735846      68.746868      0.545375
# min        0.000000             0.000000       0.000000      0.000000
# 25%    12001.250000             1.000000      51.000000      0.000000
# 50%    23919.500000             2.000000      94.000000      0.000000
# 75%    35887.750000             2.000000     178.000000      1.000000
# max    47883.000000             4.000000     220.000000      2.000000
#
#               price  number_of_reviews  calculated_host_listings_count  \
# count  48858.000000       48858.000000                    48858.000000
# mean     152.740309          23.273098                        7.148369
# std      240.232386          44.549898                       32.964600
# ...
